# %%
import sys
sys.path.insert(0,'..')
from src.server.db_api import connect

# %%
import nest_asyncio
nest_asyncio.apply()
connection = connect(host = '0.0.0.0', port = 5432) # hostname, port of the server where EVADB is running

# %%
cursor = connection.cursor()

# %% [markdown]
# ### Upload the survellience video to analyse

# %%
cursor.execute('UPLOAD INFILE "../data/bdd_test/bdd_1.mp4" PATH "bdd_video.mp4";')
response = cursor.fetch_all()
print(response)
# Out:
# Response Object:
# @status: 0
# @batch: Batch Object:
# @dataframe: Empty DataFrame
# Columns: []
# Index: []
# @batch_size: 0
# @identifier_column: id
# @metrics: None

# %% [markdown]
# ## Visualize the video

# %%
from ipywidgets import Video
Video.from_file("../data/bdd_test/bdd_1.mp4", embed=True)
# Out:
# Video(value=b'\x00\x00\x00 ftypisom\x00\x00\x02\x00isomiso2avc1mp41\x00\x00<wmoov\x00\x00\x00lmvhd\x00\x00\x00…

# %% [markdown]
# ## Load video into EVA

# %%
cursor.execute('LOAD DATA INFILE "bdd_video.mp4" INTO MyVideo;')
response = cursor.fetch_all()
print(response)
# Out:
# Response Object:
# @status: 0
# @batch: Batch Object:
# @dataframe:            Video  Num Loaded Frames
# 0  bdd_video.mp4               1203
# @batch_size: 1
# @identifier_column: id
# @metrics: None

# %% [markdown]
# ## Run the model on the loaded video

# %%
cursor.execute("""SELECT id, Unnest(FastRCNNObjectDetector(data)) FROM MyVideo""")
response = cursor.fetch_all()

# %%
response.batch.frames
# Out:
#        id                                              boxes         labels  \
# 0     407  [[461.095123291, 421.1968688965], [554.2673339...            car
# 1     407  [[559.2814331055, 419.9615783691], [656.066711...            car
# 2     407  [[645.993347168, 433.1330566406], [682.3140258...            car
# 3     408  [[463.528503418, 422.7390136719], [555.3230590...            car
# 4     408  [[644.3532104492, 434.6446228027], [680.485046...            car
# ...   ...                                                ...            ...
# 7500  180  [[344.4665527344, 307.2627258301], [371.658508...  traffic light
# 7501  180  [[208.8990478516, 152.3822479248], [237.628417...  traffic light
# 7502  180  [[1052.2082519531, 404.5354614258], [1079.6346...         person
# 7503  180  [[34.9946212769, 343.8520812988], [287.7828979...            bus
# 7504  180  [[1232.6459960938, 215.3074798584], [1278.1768...  traffic light
#
#         scores
# 0     0.997653
# 1     0.997329
# 2     0.996911
# 3     0.998743
# 4     0.996526
# ...        ...
# 7500  0.989451
# 7501  0.982935
# 7502  0.981206
# 7503  0.909774
# 7504  0.853543
#
# [7505 rows x 4 columns]

# %% [markdown]
# ## Make model inference (This section will be moved to a UDF, temporarily seeing performance now)

# %%
import pandas as pd
import torch
from torchvision import transforms

import cv2
from PIL import Image

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
number_to_make = {0: 'AM',
 1: 'Acura',
 2: 'Aston',
 3: 'Audi',
 4: 'BMW',
 5: 'Bentley',
 6: 'Bugatti',
 7: 'Buick',
 8: 'Cadillac',
 9: 'Chevrolet',
 10: 'Chrysler',
 11: 'Daewoo',
 12: 'Dodge',
 13: 'Eagle',
 14: 'FIAT',
 15: 'Ferrari',
 16: 'Fisker',
 17: 'Ford',
 18: 'GMC',
 19: 'Geo',
 20: 'HUMMER',
 21: 'Honda',
 22: 'Hyundai',
 23: 'Infiniti',
 24: 'Isuzu',
 25: 'Jaguar',
 26: 'Jeep',
 27: 'Lamborghini',
 28: 'Land',
 29: 'Lincoln',
 30: 'MINI',
 31: 'Maybach',
 32: 'Mazda',
 33: 'McLaren',
 34: 'Mercedes-Benz',
 35: 'Mitsubishi',
 36: 'Nissan',
 37: 'Plymouth',
 38: 'Porsche',
 39: 'Ram',
 40: 'Rolls-Royce',
 41: 'Scion',
 42: 'Spyker',
 43: 'Suzuki',
 44: 'Tesla',
 45: 'Toyota',
 46: 'Volkswagen',
 47: 'Volvo',
 48: 'smart'}

# %%
def infer_vehicle_makes_from_video(model, object_detections, input_path):
    
    object_detections['make_prediction'] = 'None'
    color=(0,255,0)
    thickness=3

    vcap = cv2.VideoCapture(input_path)
    width = int(vcap.get(3))
    height = int(vcap.get(4))
    fps = vcap.get(5)
    #fourcc = cv2.VideoWriter_fourcc(*'H264') #codec
    #video=cv2.VideoWriter(output_path, fourcc, fps, (width,height))

    frame_id = 0
    
    # Capture frame-by-frame
    ret, frame = vcap.read()  # ret = 1 if the video is captured; frame is the image

    while ret:
        print(frame_id)
        
        # fetch detections of all cars in this frame id
        car_detections = object_detections[(object_detections.id == frame_id) & (object_detections.labels.str.contains('car'))]
        
        for index, row in car_detections.iterrows():
            x1, y1 = row['boxes'][0]
            x2, y2 = row['boxes'][1]

            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            #print(f"Bounding rectangle: ({x1},{y1}) -> ({x2},{y2})")

            cropped_car_img = frame[y1:y2, x1:x2]
            #cv2.imshow('cropped car', cropped_car_img)
            #cv2.waitKey(0)
            
            #print("Running make inference on cropped car")
            
            img = Image.fromarray(cropped_car_img)
            image = data_transforms['valid'](img).float()
            input_image = torch.Tensor(image).unsqueeze(0).to(device)
            
            preds = model(input_image)
            label_index = int(preds.max(1)[1][0])
            #print("preds", preds)
            #print("preds softmax", torch.nn.functional.softmax(preds, dim=1))
            #print(f"class predicted for {label_index}: {number_to_make[label_index]}")
            object_detections.at[index, 'make_prediction'] = number_to_make[label_index]
                        
        frame_id+=1
        ret, frame = vcap.read()
    
    #video.release()
    vcap.release()
    cv2.destroyAllWindows()
    
    return object_detections

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
make_model = torch.load('final_make_70.pt', map_location='cpu')
make_model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=512, out_features=49, bias=True)
#   )
# )

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
input_path = '../data/bdd_test/bdd_1.mp4'
car_detections = infer_vehicle_makes_from_video(make_model, response.batch.frames, input_path)
# Out:
# 0
# Bounding rectangle: (604,433) -> (644,466)
# Bounding rectangle: (638,418) -> (743,510)
# 1
# Bounding rectangle: (602,433) -> (642,466)
# Bounding rectangle: (637,418) -> (742,508)
# 2
# Bounding rectangle: (600,431) -> (641,464)
# Bounding rectangle: (639,415) -> (741,506)
# Bounding rectangle: (586,438) -> (600,452)
# 3
# Bounding rectangle: (600,430) -> (643,464)
# Bounding rectangle: (639,416) -> (741,506)
# Bounding rectangle: (586,438) -> (601,452)
# 4
# Bounding rectangle: (600,430) -> (641,464)
# Bounding rectangle: (638,416) -> (740,506)
# 5
# Bounding rectangle: (601,430) -> (640,466)
# Bounding rectangle: (637,416) -> (743,508)
# 6
# Bounding rectangle: (600,430) -> (642,464)
# Bounding rectangle: (639,416) -> (743,505)
# 7
# Bounding rectangle: (598,431) -> (640,465)
# Bounding rectangle: (638,416) -> (738,505)
# 8
# Bounding rectangle: (599,431) -> (640,466)
# Bounding rectangle: (638,416) -> (741,505)
# 9
# Bounding rectangle: (599,430) -> (642,465)
# Bounding rectangle: (640,416) -> (742,504)
# 10
# Bounding rectangle: (597,431) -> (640,466)
# Bounding rectangle: (640,416) -> (739,505)
# 11
# Bounding rectangle: (598,431) -> (641,466)
# Bounding rectangle: (642,417) -> (741,502)
# 12
# Bounding rectangle: (598,429) -> (642,465)
# Bounding rectangle: (639,414) -> (741,500)
# 13
# Bounding rectangle: (597,431) -> (640,466)
# Bounding rectangle: (639,415) -> (739,502)
# 14
# Bounding rectangle: (596,430) -> (641,465)
# Bounding rectangle: (640,414) -> (740,500)
# 15
# Bounding rectangle: (596,430) -> (639,466)
# Bounding rectangle: (642,416) -> (741,502)
# Bounding rectangle: (727,427) -> (752,452)
# 16
# Bounding rectangle: (641,414) -> (738,497)
# Bounding rectangle: (596,430) -> (639,465)
# 17
# Bounding rectangle: (644,416) -> (739,499)
# Bounding rectangle: (597,430) -> (641,464)
# Bounding rectangle: (727,426) -> (751,451)
# 18
# Bounding rectangle: (641,412) -> (739,502)
# Bounding rectangle: (596,430) -> (641,467)
# 19
# Bounding rectangle: (640,413) -> (740,502)
# Bounding rectangle: (594,430) -> (642,467)
# 20
# Bounding rectangle: (597,428) -> (640,466)
# Bounding rectangle: (641,414) -> (741,498)
# 21
# Bounding rectangle: (594,426) -> (639,463)
# Bounding rectangle: (641,411) -> (737,494)
# Bounding rectangle: (726,425) -> (750,448)
# 22
# Bounding rectangle: (595,425) -> (639,462)
# Bounding rectangle: (643,411) -> (736,494)
# Bounding rectangle: (729,423) -> (752,447)
# 23
# Bounding rectangle: (595,427) -> (640,465)
# Bounding rectangle: (644,411) -> (737,495)
# Bounding rectangle: (729,425) -> (752,449)
# 24
# Bounding rectangle: (594,426) -> (641,463)
# Bounding rectangle: (643,411) -> (736,493)
# Bounding rectangle: (726,425) -> (750,449)
# 25
# Bounding rectangle: (643,410) -> (734,492)
# Bounding rectangle: (594,425) -> (640,462)
# Bounding rectangle: (725,423) -> (751,447)
# 26
# Bounding rectangle: (594,428) -> (641,464)
# Bounding rectangle: (645,413) -> (736,494)
# Bounding rectangle: (726,425) -> (749,449)
# 27
# Bounding rectangle: (594,427) -> (641,462)
# Bounding rectangle: (641,411) -> (735,493)
# Bounding rectangle: (725,425) -> (750,449)
# 28
# Bounding rectangle: (594,428) -> (640,463)
# Bounding rectangle: (642,413) -> (736,495)
# Bounding rectangle: (725,424) -> (750,449)
# 29
# Bounding rectangle: (596,430) -> (642,466)
# Bounding rectangle: (647,414) -> (737,497)
# 30
# Bounding rectangle: (592,431) -> (638,466)
# Bounding rectangle: (642,415) -> (734,498)
# Bounding rectangle: (725,430) -> (749,452)
# 31
# Bounding rectangle: (593,428) -> (641,464)
# Bounding rectangle: (641,414) -> (734,497)
# 32
# Bounding rectangle: (592,429) -> (642,467)
# Bounding rectangle: (645,413) -> (737,498)
# 33
# Bounding rectangle: (591,431) -> (640,468)
# Bounding rectangle: (643,414) -> (735,498)
# 34
# Bounding rectangle: (593,429) -> (644,465)
# Bounding rectangle: (643,414) -> (733,494)
# 35
# Bounding rectangle: (592,430) -> (642,467)
# Bounding rectangle: (645,415) -> (737,495)
# Bounding rectangle: (727,428) -> (752,452)
# 36
# Bounding rectangle: (592,429) -> (640,468)
# Bounding rectangle: (645,414) -> (736,497)
# Bounding rectangle: (727,427) -> (751,452)
# Bounding rectangle: (637,429) -> (657,455)
# 37
# Bounding rectangle: (593,430) -> (641,469)
# Bounding rectangle: (643,416) -> (736,497)
# Bounding rectangle: (637,431) -> (657,455)
# 38
# Bounding rectangle: (594,431) -> (641,469)
# Bounding rectangle: (645,415) -> (735,497)
# Bounding rectangle: (637,429) -> (659,454)
# 39
# Bounding rectangle: (644,418) -> (737,498)
# Bounding rectangle: (592,431) -> (641,469)
# 40
# Bounding rectangle: (591,431) -> (641,469)
# Bounding rectangle: (642,417) -> (735,499)
# Bounding rectangle: (727,428) -> (753,453)
# 41
# Bounding rectangle: (594,432) -> (641,469)
# Bounding rectangle: (645,418) -> (737,498)
# Bounding rectangle: (724,428) -> (755,456)
# Bounding rectangle: (639,435) -> (657,456)
# 42
# Bounding rectangle: (594,431) -> (640,468)
# Bounding rectangle: (645,418) -> (736,499)
# Bounding rectangle: (726,429) -> (755,455)
# Bounding rectangle: (638,433) -> (658,456)
# 43
# Bounding rectangle: (594,430) -> (639,468)
# Bounding rectangle: (645,416) -> (736,498)
# Bounding rectangle: (729,427) -> (754,452)
# Bounding rectangle: (639,431) -> (656,455)
# 44
# Bounding rectangle: (593,430) -> (641,469)
# Bounding rectangle: (645,416) -> (736,498)
# Bounding rectangle: (731,429) -> (755,453)
# Bounding rectangle: (639,432) -> (656,455)
# 45
# Bounding rectangle: (593,431) -> (640,469)
# Bounding rectangle: (645,416) -> (735,496)
# Bounding rectangle: (733,430) -> (754,453)
# 46
# Bounding rectangle: (590,433) -> (640,467)
# Bounding rectangle: (645,417) -> (736,495)
# Bounding rectangle: (730,427) -> (756,454)
# Bounding rectangle: (638,435) -> (654,456)
# 47
# Bounding rectangle: (647,416) -> (736,493)
# Bounding rectangle: (594,431) -> (641,468)
# Bounding rectangle: (733,429) -> (757,453)
# Bounding rectangle: (639,432) -> (656,455)
# Bounding rectangle: (86,441) -> (145,466)
# 48
# Bounding rectangle: (648,414) -> (738,494)
# Bounding rectangle: (593,430) -> (641,469)
# Bounding rectangle: (732,424) -> (761,454)
# 49
# Bounding rectangle: (647,415) -> (735,497)
# Bounding rectangle: (592,431) -> (642,470)
# Bounding rectangle: (734,429) -> (761,456)
# Bounding rectangle: (639,432) -> (658,456)
# Bounding rectangle: (33,439) -> (123,468)
# 50
# Bounding rectangle: (647,416) -> (737,494)
# Bounding rectangle: (593,431) -> (643,469)
# 51
# Bounding rectangle: (646,416) -> (735,495)
# Bounding rectangle: (592,431) -> (642,470)
# Bounding rectangle: (638,432) -> (659,457)
# 52
# Bounding rectangle: (646,416) -> (737,494)
# Bounding rectangle: (591,431) -> (642,469)
# 53
# Bounding rectangle: (646,416) -> (736,495)
# Bounding rectangle: (591,431) -> (642,469)
# 54
# Bounding rectangle: (648,416) -> (736,493)
# Bounding rectangle: (592,431) -> (642,469)
# Bounding rectangle: (639,432) -> (659,457)
# Bounding rectangle: (738,429) -> (765,456)
# 55
# Bounding rectangle: (649,416) -> (736,494)
# Bounding rectangle: (593,432) -> (642,470)
# Bounding rectangle: (639,433) -> (659,457)
# Bounding rectangle: (739,428) -> (766,457)
# 56
# Bounding rectangle: (650,416) -> (737,496)
# Bounding rectangle: (594,431) -> (643,471)
# Bounding rectangle: (641,433) -> (659,458)
# Bounding rectangle: (740,428) -> (769,457)
# 57
# Bounding rectangle: (593,431) -> (641,471)
# Bounding rectangle: (648,416) -> (738,496)
# Bounding rectangle: (640,435) -> (658,459)
# Bounding rectangle: (739,430) -> (767,458)
# 58
# Bounding rectangle: (649,418) -> (737,497)
# Bounding rectangle: (591,432) -> (641,472)
# Bounding rectangle: (640,435) -> (658,461)
# Bounding rectangle: (738,430) -> (775,458)
# 59
# Bounding rectangle: (638,433) -> (659,458)
# Bounding rectangle: (648,416) -> (733,497)
# Bounding rectangle: (592,431) -> (641,471)
# 60
# Bounding rectangle: (593,434) -> (641,474)
# Bounding rectangle: (651,418) -> (736,500)
# Bounding rectangle: (639,436) -> (659,463)
# Bounding rectangle: (739,432) -> (769,460)
# 61
# Bounding rectangle: (652,418) -> (736,499)
# Bounding rectangle: (593,433) -> (641,473)
# Bounding rectangle: (639,436) -> (658,463)
# 62
# Bounding rectangle: (651,422) -> (737,498)
# Bounding rectangle: (593,435) -> (641,475)
# Bounding rectangle: (639,437) -> (660,464)
# 63
# Bounding rectangle: (652,422) -> (737,498)
# Bounding rectangle: (594,435) -> (641,474)
# Bounding rectangle: (639,438) -> (660,464)
# 64
# Bounding rectangle: (592,434) -> (639,473)
# Bounding rectangle: (647,418) -> (738,499)
# Bounding rectangle: (639,437) -> (660,464)
# 65
# Bounding rectangle: (650,423) -> (736,500)
# Bounding rectangle: (592,436) -> (639,476)
# Bounding rectangle: (639,438) -> (660,465)
# 66
# Bounding rectangle: (592,434) -> (640,475)
# Bounding rectangle: (649,421) -> (737,499)
# Bounding rectangle: (639,437) -> (659,465)
# 67
# Bounding rectangle: (652,424) -> (738,499)
# Bounding rectangle: (594,435) -> (641,476)
# Bounding rectangle: (640,439) -> (661,467)
# 68
# Bounding rectangle: (652,423) -> (739,500)
# Bounding rectangle: (594,435) -> (641,476)
# Bounding rectangle: (640,438) -> (661,467)
# 69
# Bounding rectangle: (652,425) -> (738,499)
# Bounding rectangle: (593,436) -> (639,475)
# Bounding rectangle: (640,438) -> (661,468)
# 70
# Bounding rectangle: (653,425) -> (738,498)
# Bounding rectangle: (594,436) -> (639,475)
# Bounding rectangle: (640,438) -> (662,466)
# 71
# Bounding rectangle: (653,425) -> (738,500)
# Bounding rectangle: (594,437) -> (640,476)
# Bounding rectangle: (640,439) -> (662,466)
# Bounding rectangle: (751,435) -> (782,463)
# 72
# Bounding rectangle: (652,426) -> (737,499)
# Bounding rectangle: (593,436) -> (639,476)
# Bounding rectangle: (639,439) -> (661,465)
# Bounding rectangle: (751,434) -> (781,463)
# 73
# Bounding rectangle: (653,425) -> (737,498)
# Bounding rectangle: (593,436) -> (639,475)
# Bounding rectangle: (641,439) -> (661,467)
# 74
# Bounding rectangle: (652,426) -> (737,499)
# Bounding rectangle: (592,437) -> (640,477)
# Bounding rectangle: (640,441) -> (660,464)
# Bounding rectangle: (753,436) -> (783,464)
# 75
# Bounding rectangle: (652,427) -> (737,502)
# Bounding rectangle: (592,439) -> (641,480)
# Bounding rectangle: (641,441) -> (660,466)
# Bounding rectangle: (754,437) -> (784,465)
# 76
# Bounding rectangle: (594,440) -> (644,480)
# Bounding rectangle: (650,427) -> (739,505)
# Bounding rectangle: (885,439) -> (917,462)
# Bounding rectangle: (759,438) -> (788,466)
# Bounding rectangle: (643,446) -> (660,467)
# 77
# Bounding rectangle: (592,441) -> (639,480)
# Bounding rectangle: (650,428) -> (736,505)
# Bounding rectangle: (883,439) -> (916,461)
# Bounding rectangle: (760,438) -> (787,465)
# Bounding rectangle: (817,437) -> (843,463)
# Bounding rectangle: (642,445) -> (660,467)
# 78
# Bounding rectangle: (590,442) -> (641,484)
# Bounding rectangle: (649,429) -> (735,507)
# Bounding rectangle: (890,440) -> (923,462)
# Bounding rectangle: (763,440) -> (789,466)
# Bounding rectangle: (641,447) -> (660,469)
# Bounding rectangle: (819,439) -> (844,464)
# 79
# Bounding rectangle: (593,443) -> (643,483)
# Bounding rectangle: (894,441) -> (924,462)
# Bounding rectangle: (652,430) -> (738,508)
# Bounding rectangle: (766,440) -> (792,466)
# Bounding rectangle: (643,448) -> (661,469)
# 80
# Bounding rectangle: (592,443) -> (643,486)
# Bounding rectangle: (652,431) -> (737,507)
# Bounding rectangle: (768,442) -> (793,469)
# Bounding rectangle: (900,442) -> (926,462)
# Bounding rectangle: (643,451) -> (659,470)
# 81
# Bounding rectangle: (591,443) -> (643,484)
# Bounding rectangle: (650,430) -> (736,507)
# Bounding rectangle: (766,440) -> (795,468)
# Bounding rectangle: (903,441) -> (927,461)
# Bounding rectangle: (642,448) -> (659,469)
# 82
# Bounding rectangle: (592,444) -> (641,485)
# Bounding rectangle: (651,431) -> (736,508)
# Bounding rectangle: (769,442) -> (795,469)
# Bounding rectangle: (641,450) -> (659,473)
# Bounding rectangle: (907,442) -> (929,463)
# 83
# Bounding rectangle: (593,443) -> (644,486)
# Bounding rectangle: (653,431) -> (738,509)
# Bounding rectangle: (773,442) -> (798,468)
# Bounding rectangle: (644,450) -> (661,472)
# 84
# Bounding rectangle: (593,443) -> (643,482)
# Bounding rectangle: (654,430) -> (738,507)
# Bounding rectangle: (643,449) -> (661,468)
# 85
# Bounding rectangle: (652,429) -> (736,505)
# Bounding rectangle: (592,441) -> (643,482)
# Bounding rectangle: (641,445) -> (660,467)
# 86
# Bounding rectangle: (653,424) -> (736,497)
# Bounding rectangle: (591,436) -> (642,476)
# Bounding rectangle: (640,441) -> (660,461)
# 87
# Bounding rectangle: (653,425) -> (737,499)
# Bounding rectangle: (592,437) -> (640,477)
# Bounding rectangle: (640,442) -> (660,462)
# 88
# Bounding rectangle: (594,437) -> (641,478)
# Bounding rectangle: (655,425) -> (738,501)
# Bounding rectangle: (642,442) -> (661,464)
# 89
# Bounding rectangle: (594,438) -> (641,478)
# Bounding rectangle: (653,426) -> (738,501)
# Bounding rectangle: (642,445) -> (660,464)
# 90
# Bounding rectangle: (647,421) -> (734,497)
# Bounding rectangle: (588,435) -> (639,474)
# Bounding rectangle: (637,439) -> (656,460)
# 91
# Bounding rectangle: (591,433) -> (640,473)
# Bounding rectangle: (649,420) -> (739,496)
# Bounding rectangle: (641,439) -> (658,460)
# 92
# Bounding rectangle: (649,417) -> (734,489)
# Bounding rectangle: (590,430) -> (639,470)
# Bounding rectangle: (639,433) -> (658,458)
# 93
# Bounding rectangle: (647,415) -> (730,489)
# Bounding rectangle: (584,429) -> (636,469)
# Bounding rectangle: (636,430) -> (657,452)
# 94
# Bounding rectangle: (589,431) -> (640,470)
# Bounding rectangle: (651,416) -> (732,491)
# Bounding rectangle: (639,438) -> (655,455)
# 95
# Bounding rectangle: (589,431) -> (639,471)
# Bounding rectangle: (649,418) -> (734,491)
# Bounding rectangle: (638,439) -> (655,456)
# 96
# Bounding rectangle: (588,435) -> (639,473)
# Bounding rectangle: (652,421) -> (734,492)
# Bounding rectangle: (638,439) -> (657,460)
# Bounding rectangle: (786,429) -> (812,452)
# 97
# Bounding rectangle: (650,416) -> (732,488)
# Bounding rectangle: (587,431) -> (639,470)
# 98
# Bounding rectangle: (584,431) -> (636,470)
# Bounding rectangle: (647,416) -> (730,487)
# 99
# Bounding rectangle: (648,416) -> (731,489)
# Bounding rectangle: (584,432) -> (642,471)
# 100
# Bounding rectangle: (647,416) -> (729,490)
# Bounding rectangle: (583,430) -> (636,470)
# 101
# Bounding rectangle: (646,414) -> (727,487)
# Bounding rectangle: (582,429) -> (635,469)
# Bounding rectangle: (635,434) -> (650,452)
# 102
# Bounding rectangle: (582,431) -> (637,471)
# Bounding rectangle: (648,417) -> (730,490)
# Bounding rectangle: (636,437) -> (652,456)
# 103
# Bounding rectangle: (581,431) -> (636,471)
# Bounding rectangle: (648,418) -> (730,490)
# Bounding rectangle: (635,437) -> (653,457)
# 104
# Bounding rectangle: (578,432) -> (634,472)
# Bounding rectangle: (644,419) -> (725,492)
# Bounding rectangle: (633,438) -> (649,457)
# 105
# Bounding rectangle: (579,435) -> (634,474)
# Bounding rectangle: (644,420) -> (727,494)
# Bounding rectangle: (633,440) -> (649,459)
# 106
# Bounding rectangle: (580,437) -> (631,477)
# Bounding rectangle: (642,423) -> (728,497)
# Bounding rectangle: (631,439) -> (651,461)
# 107
# Bounding rectangle: (578,441) -> (633,481)
# Bounding rectangle: (644,428) -> (727,501)
# Bounding rectangle: (632,446) -> (649,465)
# Bounding rectangle: (0,474) -> (43,658)
# 108
# Bounding rectangle: (580,443) -> (632,482)
# Bounding rectangle: (643,431) -> (728,502)
# Bounding rectangle: (0,460) -> (62,664)
# 109
# Bounding rectangle: (645,431) -> (728,503)
# Bounding rectangle: (583,443) -> (632,482)
# Bounding rectangle: (0,452) -> (81,665)
# Bounding rectangle: (635,449) -> (651,467)
# 110
# Bounding rectangle: (580,444) -> (632,484)
# Bounding rectangle: (644,434) -> (729,504)
# Bounding rectangle: (0,447) -> (95,668)
# Bounding rectangle: (634,449) -> (650,469)
# 111
# Bounding rectangle: (579,444) -> (629,483)
# Bounding rectangle: (641,433) -> (724,506)
# Bounding rectangle: (0,446) -> (108,663)
# Bounding rectangle: (631,448) -> (649,468)
# 112
# Bounding rectangle: (579,442) -> (630,481)
# Bounding rectangle: (640,430) -> (725,502)
# Bounding rectangle: (0,442) -> (119,664)
# Bounding rectangle: (631,446) -> (648,466)
# Bounding rectangle: (802,436) -> (821,456)
# 113
# Bounding rectangle: (579,440) -> (631,480)
# Bounding rectangle: (641,427) -> (723,502)
# Bounding rectangle: (0,434) -> (132,664)
# Bounding rectangle: (631,445) -> (648,465)
# 114
# Bounding rectangle: (639,425) -> (724,500)
# Bounding rectangle: (578,438) -> (628,480)
# Bounding rectangle: (0,438) -> (143,668)
# Bounding rectangle: (630,444) -> (646,463)
# 115
# Bounding rectangle: (640,425) -> (725,497)
# Bounding rectangle: (580,436) -> (629,476)
# Bounding rectangle: (2,428) -> (156,666)
# Bounding rectangle: (631,442) -> (647,462)
# 116
# Bounding rectangle: (643,422) -> (726,491)
# Bounding rectangle: (580,434) -> (629,474)
# Bounding rectangle: (9,430) -> (165,662)
# Bounding rectangle: (803,428) -> (827,455)
# 117
# Bounding rectangle: (644,420) -> (725,490)
# Bounding rectangle: (579,432) -> (633,472)
# Bounding rectangle: (4,420) -> (177,662)
# Bounding rectangle: (633,436) -> (650,458)
# 118
# Bounding rectangle: (644,420) -> (726,492)
# Bounding rectangle: (581,434) -> (632,472)
# Bounding rectangle: (1,419) -> (190,661)
# 119
# Bounding rectangle: (646,419) -> (727,488)
# Bounding rectangle: (582,433) -> (634,471)
# Bounding rectangle: (1,406) -> (197,660)
# Bounding rectangle: (1117,426) -> (1154,470)
# 120
# Bounding rectangle: (643,421) -> (728,490)
# Bounding rectangle: (582,433) -> (634,471)
# Bounding rectangle: (1,383) -> (209,660)
# Bounding rectangle: (634,435) -> (654,457)
# 121
# Bounding rectangle: (643,422) -> (727,494)
# Bounding rectangle: (581,435) -> (632,473)
# Bounding rectangle: (0,370) -> (214,665)
# Bounding rectangle: (978,424) -> (1021,453)
# Bounding rectangle: (634,441) -> (649,460)
# 122
# Bounding rectangle: (645,422) -> (727,493)
# Bounding rectangle: (580,433) -> (635,473)
# Bounding rectangle: (2,365) -> (223,666)
# 123
# Bounding rectangle: (645,423) -> (727,495)
# Bounding rectangle: (582,435) -> (632,474)
# Bounding rectangle: (0,361) -> (234,675)
# Bounding rectangle: (980,426) -> (1029,455)
# Bounding rectangle: (635,437) -> (655,460)
# 124
# Bounding rectangle: (642,424) -> (727,497)
# Bounding rectangle: (580,436) -> (630,476)
# Bounding rectangle: (3,350) -> (242,669)
# Bounding rectangle: (982,427) -> (1028,455)
# Bounding rectangle: (633,440) -> (652,462)
# Bounding rectangle: (811,430) -> (831,440)
# 125
# Bounding rectangle: (645,425) -> (729,496)
# Bounding rectangle: (583,435) -> (632,474)
# Bounding rectangle: (0,342) -> (248,685)
# 126
# Bounding rectangle: (643,424) -> (727,496)
# Bounding rectangle: (582,436) -> (632,474)
# Bounding rectangle: (0,342) -> (256,676)
# Bounding rectangle: (984,429) -> (1034,456)
# Bounding rectangle: (634,441) -> (651,461)
# 127
# Bounding rectangle: (642,424) -> (725,495)
# Bounding rectangle: (579,436) -> (630,475)
# Bounding rectangle: (1,335) -> (266,681)
# Bounding rectangle: (987,428) -> (1034,457)
# Bounding rectangle: (633,440) -> (650,462)
# 128
# Bounding rectangle: (643,423) -> (727,496)
# Bounding rectangle: (579,435) -> (633,476)
# Bounding rectangle: (0,324) -> (268,677)
# Bounding rectangle: (989,428) -> (1038,456)
# Bounding rectangle: (634,441) -> (650,460)
# 129
# Bounding rectangle: (642,423) -> (725,495)
# Bounding rectangle: (579,434) -> (632,475)
# Bounding rectangle: (0,325) -> (279,678)
# Bounding rectangle: (990,427) -> (1038,455)
# 130
# Bounding rectangle: (644,422) -> (726,490)
# Bounding rectangle: (578,434) -> (633,474)
# Bounding rectangle: (997,425) -> (1044,455)
# Bounding rectangle: (1,322) -> (292,672)
# 131
# Bounding rectangle: (642,422) -> (727,492)
# Bounding rectangle: (579,432) -> (633,474)
# Bounding rectangle: (3,304) -> (296,690)
# Bounding rectangle: (997,424) -> (1047,454)
# Bounding rectangle: (634,437) -> (652,457)
# 132
# Bounding rectangle: (642,421) -> (726,491)
# Bounding rectangle: (576,431) -> (631,472)
# Bounding rectangle: (4,315) -> (302,690)
# Bounding rectangle: (998,423) -> (1047,453)
# 133
# Bounding rectangle: (643,419) -> (724,488)
# Bounding rectangle: (577,431) -> (632,472)
# Bounding rectangle: (5,312) -> (309,679)
# Bounding rectangle: (997,422) -> (1050,453)
# 134
# Bounding rectangle: (642,419) -> (725,488)
# Bounding rectangle: (578,430) -> (632,472)
# Bounding rectangle: (5,321) -> (318,671)
# Bounding rectangle: (1001,421) -> (1052,453)
# 135
# Bounding rectangle: (644,419) -> (727,487)
# Bounding rectangle: (578,430) -> (632,470)
# Bounding rectangle: (0,313) -> (318,672)
# Bounding rectangle: (1003,421) -> (1057,451)
# 136
# Bounding rectangle: (643,419) -> (725,487)
# Bounding rectangle: (577,431) -> (631,471)
# Bounding rectangle: (0,314) -> (327,667)
# Bounding rectangle: (1003,421) -> (1061,453)
# 137
# Bounding rectangle: (643,420) -> (726,489)
# Bounding rectangle: (578,431) -> (631,471)
# Bounding rectangle: (1007,421) -> (1064,453)
# Bounding rectangle: (0,314) -> (335,671)
# Bounding rectangle: (634,435) -> (652,455)
# 138
# Bounding rectangle: (643,421) -> (727,490)
# Bounding rectangle: (579,432) -> (633,474)
# Bounding rectangle: (0,315) -> (334,668)
# Bounding rectangle: (1019,423) -> (1072,455)
# Bounding rectangle: (634,436) -> (653,457)
# 139
# Bounding rectangle: (645,418) -> (726,493)
# Bounding rectangle: (579,431) -> (633,474)
# Bounding rectangle: (3,314) -> (336,670)
# Bounding rectangle: (1019,422) -> (1073,455)
# Bounding rectangle: (635,436) -> (653,456)
# 140
# Bounding rectangle: (644,421) -> (727,490)
# Bounding rectangle: (581,431) -> (633,472)
# Bounding rectangle: (2,313) -> (345,671)
# Bounding rectangle: (635,435) -> (654,456)
# 141
# Bounding rectangle: (645,423) -> (726,493)
# Bounding rectangle: (580,433) -> (633,476)
# Bounding rectangle: (1,311) -> (355,663)
# Bounding rectangle: (635,437) -> (653,459)
# Bounding rectangle: (1022,426) -> (1082,459)
# 142
# Bounding rectangle: (644,422) -> (728,492)
# Bounding rectangle: (580,433) -> (634,475)
# Bounding rectangle: (635,438) -> (653,458)
# Bounding rectangle: (1033,426) -> (1088,458)
# Bounding rectangle: (0,313) -> (353,661)
# 143
# Bounding rectangle: (646,424) -> (728,495)
# Bounding rectangle: (581,434) -> (635,477)
# Bounding rectangle: (0,319) -> (357,664)
# Bounding rectangle: (637,439) -> (655,460)
# 144
# Bounding rectangle: (644,427) -> (726,494)
# Bounding rectangle: (580,435) -> (633,477)
# Bounding rectangle: (0,321) -> (368,662)
# Bounding rectangle: (634,440) -> (653,460)
# 145
# Bounding rectangle: (644,427) -> (725,495)
# Bounding rectangle: (580,434) -> (632,478)
# Bounding rectangle: (2,323) -> (373,655)
# Bounding rectangle: (635,440) -> (653,461)
# 146
# Bounding rectangle: (645,427) -> (726,495)
# Bounding rectangle: (580,434) -> (633,478)
# Bounding rectangle: (3,322) -> (388,655)
# Bounding rectangle: (635,440) -> (653,460)
# Bounding rectangle: (825,430) -> (846,442)
# Bounding rectangle: (1043,429) -> (1103,463)
# 147
# Bounding rectangle: (644,428) -> (725,497)
# Bounding rectangle: (579,435) -> (632,479)
# Bounding rectangle: (5,332) -> (374,656)
# Bounding rectangle: (634,440) -> (652,462)
# Bounding rectangle: (967,428) -> (1022,462)
# 148
# Bounding rectangle: (645,427) -> (725,497)
# Bounding rectangle: (578,436) -> (631,479)
# Bounding rectangle: (3,330) -> (384,657)
# Bounding rectangle: (634,441) -> (652,462)
# Bounding rectangle: (824,431) -> (846,444)
# Bounding rectangle: (966,427) -> (1024,464)
# Bounding rectangle: (923,426) -> (978,470)
# 149
# Bounding rectangle: (643,429) -> (724,497)
# Bounding rectangle: (578,435) -> (631,479)
# Bounding rectangle: (4,337) -> (396,659)
# Bounding rectangle: (634,440) -> (652,462)
# Bounding rectangle: (825,431) -> (847,444)
# 150
# Bounding rectangle: (578,436) -> (632,479)
# Bounding rectangle: (645,428) -> (725,497)
# Bounding rectangle: (2,339) -> (400,658)
# Bounding rectangle: (1044,429) -> (1120,463)
# Bounding rectangle: (828,431) -> (849,444)
# Bounding rectangle: (635,441) -> (652,461)
# 151
# Bounding rectangle: (579,435) -> (633,478)
# Bounding rectangle: (645,426) -> (726,495)
# Bounding rectangle: (1044,428) -> (1125,464)
# Bounding rectangle: (8,339) -> (401,650)
# Bounding rectangle: (829,431) -> (852,443)
# Bounding rectangle: (636,439) -> (657,461)
# Bounding rectangle: (964,425) -> (1037,463)
# 152
# Bounding rectangle: (645,426) -> (726,494)
# Bounding rectangle: (579,435) -> (633,478)
# Bounding rectangle: (0,339) -> (393,650)
# Bounding rectangle: (829,429) -> (852,443)
# Bounding rectangle: (1052,428) -> (1129,463)
# Bounding rectangle: (825,429) -> (852,455)
# 153
# Bounding rectangle: (646,426) -> (727,493)
# Bounding rectangle: (579,435) -> (633,477)
# Bounding rectangle: (1052,428) -> (1133,462)
# Bounding rectangle: (0,341) -> (402,650)
# Bounding rectangle: (831,429) -> (853,442)
# Bounding rectangle: (636,439) -> (656,460)
# 154
# Bounding rectangle: (579,435) -> (633,477)
# Bounding rectangle: (644,424) -> (726,495)
# Bounding rectangle: (2,343) -> (421,656)
# Bounding rectangle: (831,429) -> (854,442)
# Bounding rectangle: (635,438) -> (656,460)
# 155
# Bounding rectangle: (647,426) -> (728,495)
# Bounding rectangle: (581,433) -> (634,476)
# Bounding rectangle: (4,343) -> (422,657)
# Bounding rectangle: (831,426) -> (855,452)
# Bounding rectangle: (637,441) -> (654,460)
# 156
# Bounding rectangle: (578,434) -> (632,476)
# Bounding rectangle: (645,426) -> (726,494)
# Bounding rectangle: (5,349) -> (418,655)
# Bounding rectangle: (635,440) -> (654,460)
# 157
# Bounding rectangle: (580,435) -> (633,477)
# Bounding rectangle: (646,428) -> (726,496)
# Bounding rectangle: (6,352) -> (419,655)
# Bounding rectangle: (635,440) -> (654,461)
# Bounding rectangle: (829,429) -> (856,457)
# 158
# Bounding rectangle: (582,434) -> (635,477)
# Bounding rectangle: (647,427) -> (728,496)
# Bounding rectangle: (11,353) -> (436,656)
# Bounding rectangle: (636,440) -> (655,460)
# 159
# Bounding rectangle: (580,435) -> (632,479)
# Bounding rectangle: (647,427) -> (726,498)
# Bounding rectangle: (9,364) -> (436,658)
# Bounding rectangle: (635,441) -> (655,462)
# Bounding rectangle: (834,430) -> (858,448)
# 160
# Bounding rectangle: (649,429) -> (727,496)
# Bounding rectangle: (581,435) -> (634,479)
# Bounding rectangle: (13,367) -> (429,658)
# Bounding rectangle: (636,442) -> (656,462)
# Bounding rectangle: (836,431) -> (860,446)
# 161
# Bounding rectangle: (581,435) -> (634,479)
# Bounding rectangle: (647,428) -> (727,496)
# Bounding rectangle: (2,361) -> (438,650)
# Bounding rectangle: (637,441) -> (655,462)
# Bounding rectangle: (838,430) -> (861,446)
# 162
# Bounding rectangle: (646,429) -> (725,497)
# Bounding rectangle: (580,435) -> (632,478)
# Bounding rectangle: (10,366) -> (437,649)
# Bounding rectangle: (635,441) -> (655,461)
# Bounding rectangle: (833,429) -> (860,456)
# Bounding rectangle: (1086,429) -> (1180,467)
# 163
# Bounding rectangle: (645,428) -> (725,496)
# Bounding rectangle: (579,434) -> (632,476)
# Bounding rectangle: (9,368) -> (442,652)
# Bounding rectangle: (636,440) -> (654,460)
# 164
# Bounding rectangle: (582,433) -> (635,474)
# Bounding rectangle: (648,425) -> (729,494)
# Bounding rectangle: (14,362) -> (445,642)
# Bounding rectangle: (637,439) -> (657,459)
# 165
# Bounding rectangle: (646,421) -> (728,489)
# Bounding rectangle: (580,431) -> (633,472)
# Bounding rectangle: (0,359) -> (447,641)
# Bounding rectangle: (637,435) -> (656,456)
# 166
# Bounding rectangle: (646,421) -> (726,489)
# Bounding rectangle: (580,431) -> (633,472)
# Bounding rectangle: (2,362) -> (452,634)
# Bounding rectangle: (636,435) -> (655,456)
# Bounding rectangle: (1103,422) -> (1188,463)
# 167
# Bounding rectangle: (647,420) -> (728,486)
# Bounding rectangle: (579,429) -> (633,470)
# Bounding rectangle: (2,356) -> (454,637)
# Bounding rectangle: (1108,421) -> (1199,457)
# Bounding rectangle: (637,433) -> (655,454)
# 168
# Bounding rectangle: (578,429) -> (635,471)
# Bounding rectangle: (646,418) -> (726,487)
# Bounding rectangle: (7,358) -> (451,644)
# Bounding rectangle: (1113,419) -> (1207,460)
# Bounding rectangle: (637,431) -> (657,454)
# 169
# Bounding rectangle: (646,416) -> (726,486)
# Bounding rectangle: (8,359) -> (459,630)
# Bounding rectangle: (579,428) -> (633,470)
# 170
# Bounding rectangle: (647,420) -> (730,486)
# Bounding rectangle: (12,355) -> (455,625)
# Bounding rectangle: (580,430) -> (634,472)
# Bounding rectangle: (1062,414) -> (1108,460)
# Bounding rectangle: (1131,422) -> (1236,478)
# 171
# Bounding rectangle: (648,419) -> (731,484)
# Bounding rectangle: (582,430) -> (636,469)
# Bounding rectangle: (19,354) -> (466,626)
# Bounding rectangle: (875,420) -> (922,458)
# Bounding rectangle: (639,431) -> (659,453)
# 172
# Bounding rectangle: (645,415) -> (729,484)
# Bounding rectangle: (582,427) -> (634,467)
# Bounding rectangle: (21,349) -> (463,622)
# Bounding rectangle: (1148,416) -> (1246,473)
# Bounding rectangle: (636,427) -> (658,450)
# 173
# Bounding rectangle: (647,417) -> (728,485)
# Bounding rectangle: (582,428) -> (634,470)
# Bounding rectangle: (40,350) -> (470,618)
# Bounding rectangle: (1132,417) -> (1248,457)
# Bounding rectangle: (637,429) -> (658,452)
# 174
# Bounding rectangle: (650,419) -> (731,487)
# Bounding rectangle: (581,429) -> (634,471)
# Bounding rectangle: (57,353) -> (468,617)
# Bounding rectangle: (1147,418) -> (1261,460)
# 175
# Bounding rectangle: (646,419) -> (729,486)
# Bounding rectangle: (580,430) -> (634,471)
# Bounding rectangle: (60,357) -> (472,615)
# 176
# Bounding rectangle: (580,430) -> (636,471)
# Bounding rectangle: (648,416) -> (730,487)
# Bounding rectangle: (59,357) -> (478,617)
# Bounding rectangle: (1153,418) -> (1264,459)
# 177
# Bounding rectangle: (581,430) -> (636,472)
# Bounding rectangle: (648,419) -> (729,488)
# Bounding rectangle: (74,361) -> (481,615)
# Bounding rectangle: (1154,420) -> (1273,460)
# 178
# Bounding rectangle: (581,430) -> (634,473)
# Bounding rectangle: (84,366) -> (481,611)
# Bounding rectangle: (647,420) -> (731,488)
# Bounding rectangle: (637,433) -> (659,455)
# 179
# Bounding rectangle: (581,431) -> (634,475)
# Bounding rectangle: (86,369) -> (482,613)
# Bounding rectangle: (648,422) -> (732,489)
# Bounding rectangle: (638,436) -> (658,456)
# Bounding rectangle: (1169,417) -> (1253,435)
# 180
# Bounding rectangle: (584,432) -> (635,474)
# Bounding rectangle: (651,422) -> (730,489)
# Bounding rectangle: (98,368) -> (483,608)
# 181
# Bounding rectangle: (583,435) -> (635,477)
# Bounding rectangle: (650,424) -> (733,492)
# Bounding rectangle: (98,369) -> (482,613)
# Bounding rectangle: (1183,418) -> (1276,438)
# Bounding rectangle: (639,439) -> (659,458)
# 182
# Bounding rectangle: (584,436) -> (634,479)
# Bounding rectangle: (651,425) -> (732,492)
# Bounding rectangle: (117,373) -> (484,611)
# Bounding rectangle: (1185,417) -> (1276,439)
# Bounding rectangle: (640,440) -> (660,460)
# 183
# Bounding rectangle: (585,435) -> (634,476)
# Bounding rectangle: (126,374) -> (487,606)
# Bounding rectangle: (651,424) -> (731,491)
# Bounding rectangle: (1179,416) -> (1274,462)
# Bounding rectangle: (641,440) -> (659,458)
# 184
# Bounding rectangle: (583,435) -> (634,478)
# Bounding rectangle: (121,380) -> (490,606)
# Bounding rectangle: (650,424) -> (730,490)
# 185
# Bounding rectangle: (585,433) -> (638,476)
# Bounding rectangle: (652,422) -> (732,491)
# Bounding rectangle: (141,380) -> (495,602)
# Bounding rectangle: (1196,413) -> (1276,459)
# 186
# Bounding rectangle: (585,435) -> (639,478)
# Bounding rectangle: (653,424) -> (734,492)
# Bounding rectangle: (148,384) -> (490,601)
# Bounding rectangle: (1199,414) -> (1279,463)
# Bounding rectangle: (643,440) -> (661,460)
# 187
# Bounding rectangle: (586,432) -> (638,475)
# Bounding rectangle: (653,422) -> (733,489)
# Bounding rectangle: (156,386) -> (498,603)
# Bounding rectangle: (1195,412) -> (1277,461)
# 188
# Bounding rectangle: (586,435) -> (639,478)
# Bounding rectangle: (653,424) -> (733,491)
# Bounding rectangle: (162,387) -> (499,602)
# Bounding rectangle: (643,440) -> (661,460)
# Bounding rectangle: (1223,412) -> (1280,459)
# 189
# Bounding rectangle: (587,435) -> (639,477)
# Bounding rectangle: (651,423) -> (734,489)
# Bounding rectangle: (166,389) -> (502,600)
# 190
# Bounding rectangle: (587,434) -> (640,478)
# Bounding rectangle: (178,389) -> (506,603)
# Bounding rectangle: (654,423) -> (733,492)
# Bounding rectangle: (1011,415) -> (1056,458)
# 191
# Bounding rectangle: (587,436) -> (640,479)
# Bounding rectangle: (185,393) -> (505,597)
# Bounding rectangle: (653,424) -> (734,494)
# Bounding rectangle: (1003,415) -> (1069,461)
# 192
# Bounding rectangle: (589,435) -> (638,476)
# Bounding rectangle: (187,390) -> (506,595)
# Bounding rectangle: (654,426) -> (734,492)
# Bounding rectangle: (1014,415) -> (1077,462)
# 193
# Bounding rectangle: (589,436) -> (638,476)
# Bounding rectangle: (194,395) -> (512,594)
# Bounding rectangle: (652,426) -> (734,488)
# Bounding rectangle: (1010,415) -> (1077,458)
# 194
# Bounding rectangle: (588,434) -> (639,475)
# Bounding rectangle: (197,391) -> (512,595)
# Bounding rectangle: (655,424) -> (735,491)
# Bounding rectangle: (1026,411) -> (1097,460)
# 195
# Bounding rectangle: (655,424) -> (734,491)
# Bounding rectangle: (589,432) -> (639,474)
# Bounding rectangle: (204,385) -> (526,592)
# 196
# Bounding rectangle: (590,433) -> (638,474)
# Bounding rectangle: (224,389) -> (514,582)
# Bounding rectangle: (655,424) -> (735,490)
# 197
# Bounding rectangle: (589,431) -> (641,473)
# Bounding rectangle: (227,383) -> (516,577)
# Bounding rectangle: (656,422) -> (736,488)
# 198
# Bounding rectangle: (235,383) -> (518,572)
# Bounding rectangle: (588,430) -> (641,471)
# Bounding rectangle: (654,420) -> (735,484)
# 199
# Bounding rectangle: (589,429) -> (641,470)
# Bounding rectangle: (239,383) -> (514,569)
# Bounding rectangle: (654,419) -> (736,483)
# Bounding rectangle: (1072,406) -> (1142,461)
# 200
# Bounding rectangle: (590,429) -> (642,469)
# Bounding rectangle: (655,417) -> (737,481)
# Bounding rectangle: (236,382) -> (522,569)
# 201
# Bounding rectangle: (654,418) -> (737,483)
# Bounding rectangle: (589,429) -> (642,469)
# Bounding rectangle: (235,382) -> (522,568)
# Bounding rectangle: (1083,407) -> (1167,462)
# 202
# Bounding rectangle: (656,418) -> (739,484)
# Bounding rectangle: (590,428) -> (642,467)
# Bounding rectangle: (240,382) -> (522,573)
# Bounding rectangle: (1078,406) -> (1178,461)
# 203
# Bounding rectangle: (589,430) -> (643,471)
# Bounding rectangle: (657,420) -> (740,486)
# Bounding rectangle: (247,385) -> (523,572)
# Bounding rectangle: (1101,410) -> (1195,459)
# 204
# Bounding rectangle: (592,429) -> (647,470)
# Bounding rectangle: (254,385) -> (531,567)
# Bounding rectangle: (660,418) -> (742,484)
# Bounding rectangle: (1098,411) -> (1204,465)
# Bounding rectangle: (938,411) -> (998,432)
# 205
# Bounding rectangle: (659,419) -> (739,485)
# Bounding rectangle: (260,384) -> (532,566)
# Bounding rectangle: (592,429) -> (644,470)
# Bounding rectangle: (1107,413) -> (1214,466)
# Bounding rectangle: (939,413) -> (999,433)
# 206
# Bounding rectangle: (270,387) -> (533,565)
# Bounding rectangle: (593,431) -> (645,472)
# Bounding rectangle: (659,420) -> (740,488)
# Bounding rectangle: (1119,413) -> (1229,466)
# 207
# Bounding rectangle: (271,386) -> (535,566)
# Bounding rectangle: (594,430) -> (647,473)
# Bounding rectangle: (662,420) -> (741,488)
# Bounding rectangle: (1122,413) -> (1232,469)
# Bounding rectangle: (651,436) -> (671,454)
# Bounding rectangle: (941,415) -> (1007,439)
# 208
# Bounding rectangle: (280,388) -> (535,563)
# Bounding rectangle: (591,433) -> (642,474)
# Bounding rectangle: (658,423) -> (739,491)
# Bounding rectangle: (1129,415) -> (1234,470)
# Bounding rectangle: (946,416) -> (1010,439)
# Bounding rectangle: (1038,415) -> (1137,460)
# 209
# Bounding rectangle: (592,432) -> (643,475)
# Bounding rectangle: (284,388) -> (534,561)
# Bounding rectangle: (659,421) -> (739,491)
# Bounding rectangle: (1133,415) -> (1253,473)
# Bounding rectangle: (947,416) -> (1013,439)
# Bounding rectangle: (1038,414) -> (1142,468)
# Bounding rectangle: (877,421) -> (947,462)
# 210
# Bounding rectangle: (285,387) -> (538,562)
# Bounding rectangle: (594,431) -> (647,474)
# Bounding rectangle: (660,423) -> (741,490)
# Bounding rectangle: (1135,415) -> (1264,472)
# Bounding rectangle: (1042,413) -> (1147,466)
# Bounding rectangle: (876,421) -> (949,461)
# Bounding rectangle: (947,416) -> (1015,439)
# 211
# Bounding rectangle: (294,387) -> (544,553)
# Bounding rectangle: (596,431) -> (646,471)
# Bounding rectangle: (662,421) -> (741,488)
# Bounding rectangle: (1144,414) -> (1273,472)
# Bounding rectangle: (879,420) -> (953,460)
# Bounding rectangle: (1052,414) -> (1157,463)
# Bounding rectangle: (953,415) -> (1020,438)
# Bounding rectangle: (944,416) -> (1025,466)
# 212
# Bounding rectangle: (292,389) -> (539,554)
# Bounding rectangle: (593,432) -> (646,476)
# Bounding rectangle: (660,423) -> (739,490)
# Bounding rectangle: (879,422) -> (946,461)
# 213
# Bounding rectangle: (297,388) -> (541,550)
# Bounding rectangle: (593,431) -> (645,474)
# Bounding rectangle: (659,423) -> (740,491)
# Bounding rectangle: (1132,414) -> (1275,474)
# Bounding rectangle: (950,415) -> (1022,438)
# Bounding rectangle: (878,420) -> (953,461)
# 214
# Bounding rectangle: (309,390) -> (541,542)
# Bounding rectangle: (662,421) -> (740,487)
# Bounding rectangle: (595,430) -> (646,472)
# Bounding rectangle: (1172,415) -> (1272,468)
# 215
# Bounding rectangle: (305,387) -> (543,553)
# Bounding rectangle: (594,429) -> (647,474)
# Bounding rectangle: (663,424) -> (742,490)
# 216
# Bounding rectangle: (311,389) -> (542,547)
# Bounding rectangle: (661,421) -> (740,488)
# Bounding rectangle: (595,429) -> (647,472)
# 217
# Bounding rectangle: (316,389) -> (545,549)
# Bounding rectangle: (662,423) -> (740,487)
# Bounding rectangle: (596,430) -> (648,472)
# Bounding rectangle: (970,413) -> (1038,437)
# 218
# Bounding rectangle: (315,390) -> (549,550)
# Bounding rectangle: (661,422) -> (743,489)
# Bounding rectangle: (595,430) -> (648,473)
# Bounding rectangle: (971,412) -> (1047,437)
# Bounding rectangle: (907,419) -> (953,449)
# 219
# Bounding rectangle: (315,390) -> (547,551)
# Bounding rectangle: (660,423) -> (739,490)
# Bounding rectangle: (592,430) -> (645,474)
# Bounding rectangle: (969,412) -> (1045,436)
# Bounding rectangle: (1090,410) -> (1189,455)
# 220
# Bounding rectangle: (326,393) -> (548,546)
# Bounding rectangle: (660,424) -> (737,487)
# Bounding rectangle: (591,430) -> (646,473)
# Bounding rectangle: (972,412) -> (1046,437)
# Bounding rectangle: (1089,409) -> (1192,453)
# Bounding rectangle: (1151,409) -> (1275,471)
# 221
# Bounding rectangle: (326,393) -> (550,546)
# Bounding rectangle: (662,422) -> (742,487)
# Bounding rectangle: (596,429) -> (648,473)
# Bounding rectangle: (986,410) -> (1059,435)
# Bounding rectangle: (1099,408) -> (1211,458)
# 222
# Bounding rectangle: (328,394) -> (551,548)
# Bounding rectangle: (665,424) -> (744,489)
# Bounding rectangle: (598,432) -> (648,476)
# Bounding rectangle: (1178,408) -> (1275,473)
# Bounding rectangle: (990,410) -> (1064,436)
# Bounding rectangle: (1109,407) -> (1221,459)
# 223
# Bounding rectangle: (336,396) -> (551,547)
# Bounding rectangle: (663,425) -> (740,488)
# Bounding rectangle: (597,431) -> (648,474)
# Bounding rectangle: (1101,407) -> (1219,460)
# Bounding rectangle: (986,409) -> (1058,434)
# Bounding rectangle: (1178,407) -> (1274,471)
# 224
# Bounding rectangle: (337,399) -> (551,544)
# Bounding rectangle: (665,426) -> (742,491)
# Bounding rectangle: (600,436) -> (648,475)
# Bounding rectangle: (990,412) -> (1071,437)
# Bounding rectangle: (1118,408) -> (1231,465)
# 225
# Bounding rectangle: (339,401) -> (552,547)
# Bounding rectangle: (666,429) -> (744,492)
# Bounding rectangle: (1123,408) -> (1247,473)
# Bounding rectangle: (601,438) -> (649,478)
# Bounding rectangle: (1002,412) -> (1078,439)
# 226
# Bounding rectangle: (336,402) -> (557,548)
# Bounding rectangle: (663,430) -> (739,494)
# Bounding rectangle: (599,440) -> (647,479)
# Bounding rectangle: (1119,407) -> (1238,471)
# Bounding rectangle: (996,413) -> (1074,440)
# Bounding rectangle: (653,443) -> (671,461)
# 227
# Bounding rectangle: (347,405) -> (554,547)
# Bounding rectangle: (663,431) -> (739,494)
# Bounding rectangle: (600,442) -> (646,479)
# Bounding rectangle: (1114,409) -> (1252,475)
# Bounding rectangle: (997,414) -> (1077,441)
# 228
# Bounding rectangle: (664,430) -> (745,496)
# Bounding rectangle: (353,407) -> (556,551)
# Bounding rectangle: (603,446) -> (649,482)
# Bounding rectangle: (1128,411) -> (1272,478)
# Bounding rectangle: (929,425) -> (975,447)
# Bounding rectangle: (1005,417) -> (1090,443)
# Bounding rectangle: (1220,422) -> (1278,487)
# 229
# Bounding rectangle: (665,432) -> (744,497)
# Bounding rectangle: (348,402) -> (557,551)
# Bounding rectangle: (602,446) -> (649,482)
# Bounding rectangle: (1140,411) -> (1272,476)
# Bounding rectangle: (1012,416) -> (1096,444)
# Bounding rectangle: (932,425) -> (980,447)
# Bounding rectangle: (1230,432) -> (1279,485)
# 230
# Bounding rectangle: (663,433) -> (741,497)
# Bounding rectangle: (352,407) -> (559,550)
# Bounding rectangle: (599,445) -> (646,482)
# Bounding rectangle: (1134,411) -> (1274,477)
# Bounding rectangle: (1011,417) -> (1092,445)
# Bounding rectangle: (925,426) -> (974,448)
# 231
# Bounding rectangle: (357,410) -> (561,550)
# Bounding rectangle: (662,433) -> (743,498)
# Bounding rectangle: (1149,411) -> (1278,478)
# Bounding rectangle: (602,445) -> (650,483)
# Bounding rectangle: (1022,418) -> (1104,445)
# 232
# Bounding rectangle: (662,430) -> (743,499)
# Bounding rectangle: (359,408) -> (560,551)
# Bounding rectangle: (599,445) -> (646,482)
# Bounding rectangle: (939,425) -> (988,448)
# Bounding rectangle: (1021,415) -> (1108,444)
# Bounding rectangle: (1164,410) -> (1279,472)
# 233
# Bounding rectangle: (355,408) -> (562,545)
# Bounding rectangle: (663,429) -> (741,494)
# Bounding rectangle: (599,439) -> (647,479)
# Bounding rectangle: (1030,413) -> (1106,441)
# Bounding rectangle: (1160,408) -> (1279,473)
# Bounding rectangle: (929,422) -> (985,446)
# 234
# Bounding rectangle: (363,407) -> (567,543)
# Bounding rectangle: (662,427) -> (740,492)
# Bounding rectangle: (598,438) -> (647,478)
# Bounding rectangle: (1034,411) -> (1109,439)
# Bounding rectangle: (935,420) -> (987,442)
# Bounding rectangle: (1166,406) -> (1279,473)
# Bounding rectangle: (1004,420) -> (1042,439)
# 235
# Bounding rectangle: (665,430) -> (742,495)
# Bounding rectangle: (362,405) -> (564,546)
# Bounding rectangle: (1068,411) -> (1126,441)
# Bounding rectangle: (601,444) -> (646,480)
# Bounding rectangle: (927,420) -> (1002,465)
# 236
# Bounding rectangle: (361,407) -> (569,543)
# Bounding rectangle: (600,437) -> (647,475)
# Bounding rectangle: (664,426) -> (740,491)
# Bounding rectangle: (1039,405) -> (1130,479)
# Bounding rectangle: (1045,406) -> (1126,442)
# 237
# Bounding rectangle: (371,405) -> (570,540)
# Bounding rectangle: (602,435) -> (652,476)
# Bounding rectangle: (666,426) -> (742,491)
# Bounding rectangle: (947,417) -> (997,440)
# Bounding rectangle: (1047,406) -> (1129,441)
# 238
# Bounding rectangle: (600,432) -> (651,473)
# Bounding rectangle: (664,422) -> (741,487)
# Bounding rectangle: (374,401) -> (571,540)
# Bounding rectangle: (947,415) -> (999,437)
# Bounding rectangle: (1055,403) -> (1141,433)
# Bounding rectangle: (1010,413) -> (1063,433)
# 239
# Bounding rectangle: (662,422) -> (740,490)
# Bounding rectangle: (371,403) -> (565,538)
# Bounding rectangle: (598,433) -> (647,472)
# Bounding rectangle: (1075,399) -> (1153,431)
# 240
# Bounding rectangle: (601,432) -> (652,473)
# Bounding rectangle: (664,423) -> (743,490)
# Bounding rectangle: (375,405) -> (571,542)
# Bounding rectangle: (956,412) -> (1009,433)
# Bounding rectangle: (1068,401) -> (1158,432)
# Bounding rectangle: (1027,412) -> (1074,432)
# 241
# Bounding rectangle: (664,424) -> (741,490)
# Bounding rectangle: (601,434) -> (650,472)
# Bounding rectangle: (378,406) -> (574,540)
# Bounding rectangle: (1062,400) -> (1158,432)
# Bounding rectangle: (1022,412) -> (1071,433)
# 242
# Bounding rectangle: (660,421) -> (740,491)
# Bounding rectangle: (598,432) -> (648,474)
# Bounding rectangle: (378,404) -> (568,540)
# Bounding rectangle: (1076,396) -> (1177,432)
# Bounding rectangle: (1072,398) -> (1178,463)
# 243
# Bounding rectangle: (664,420) -> (746,490)
# Bounding rectangle: (379,401) -> (572,540)
# Bounding rectangle: (600,430) -> (652,473)
# Bounding rectangle: (1077,396) -> (1184,430)
# Bounding rectangle: (967,407) -> (1024,434)
# Bounding rectangle: (1035,408) -> (1090,431)
# 244
# Bounding rectangle: (603,432) -> (652,472)
# Bounding rectangle: (383,402) -> (573,540)
# Bounding rectangle: (664,421) -> (742,489)
# Bounding rectangle: (1082,396) -> (1179,429)
# Bounding rectangle: (957,409) -> (1017,432)
# Bounding rectangle: (1041,409) -> (1087,429)
# 245
# Bounding rectangle: (600,433) -> (649,472)
# Bounding rectangle: (389,405) -> (576,536)
# Bounding rectangle: (662,425) -> (738,491)
# Bounding rectangle: (965,413) -> (1020,434)
# Bounding rectangle: (1085,398) -> (1188,433)
# Bounding rectangle: (1040,412) -> (1092,432)
# 246
# Bounding rectangle: (663,429) -> (742,493)
# Bounding rectangle: (389,410) -> (573,538)
# Bounding rectangle: (601,438) -> (649,477)
# Bounding rectangle: (979,415) -> (1029,441)
# Bounding rectangle: (1088,401) -> (1203,442)
# Bounding rectangle: (1046,414) -> (1104,438)
# 247
# Bounding rectangle: (667,431) -> (745,496)
# Bounding rectangle: (390,411) -> (575,546)
# Bounding rectangle: (605,441) -> (654,479)
# Bounding rectangle: (984,417) -> (1036,442)
# Bounding rectangle: (1103,404) -> (1214,440)
# Bounding rectangle: (1062,416) -> (1110,440)
# 248
# Bounding rectangle: (662,430) -> (742,495)
# Bounding rectangle: (387,407) -> (576,543)
# Bounding rectangle: (603,439) -> (650,477)
# Bounding rectangle: (985,416) -> (1035,441)
# Bounding rectangle: (1107,402) -> (1217,439)
# Bounding rectangle: (1063,416) -> (1111,438)
# 249
# Bounding rectangle: (665,431) -> (742,494)
# Bounding rectangle: (606,439) -> (652,477)
# Bounding rectangle: (399,413) -> (579,540)
# Bounding rectangle: (984,418) -> (1037,443)
# Bounding rectangle: (1109,404) -> (1223,440)
# Bounding rectangle: (1057,417) -> (1112,441)
# 250
# Bounding rectangle: (401,414) -> (575,540)
# Bounding rectangle: (663,431) -> (739,497)
# Bounding rectangle: (604,441) -> (649,478)
# Bounding rectangle: (1130,404) -> (1236,443)
# Bounding rectangle: (1071,419) -> (1123,442)
# Bounding rectangle: (976,418) -> (1044,462)
# 251
# Bounding rectangle: (661,430) -> (741,502)
# Bounding rectangle: (1137,403) -> (1248,442)
# Bounding rectangle: (397,411) -> (576,541)
# Bounding rectangle: (601,441) -> (648,481)
# Bounding rectangle: (987,417) -> (1049,445)
# 252
# Bounding rectangle: (662,428) -> (741,496)
# Bounding rectangle: (603,437) -> (649,477)
# Bounding rectangle: (406,411) -> (578,540)
# Bounding rectangle: (1135,401) -> (1249,438)
# Bounding rectangle: (988,416) -> (1047,443)
# Bounding rectangle: (1070,416) -> (1130,440)
# 253
# Bounding rectangle: (603,433) -> (650,471)
# Bounding rectangle: (663,427) -> (740,492)
# Bounding rectangle: (409,408) -> (579,530)
# Bounding rectangle: (1001,413) -> (1053,439)
# Bounding rectangle: (1147,397) -> (1270,435)
# Bounding rectangle: (1088,413) -> (1140,437)
# 254
# Bounding rectangle: (405,403) -> (581,524)
# Bounding rectangle: (602,432) -> (651,470)
# Bounding rectangle: (664,418) -> (743,491)
# Bounding rectangle: (1009,407) -> (1068,436)
# Bounding rectangle: (1103,407) -> (1155,432)
# Bounding rectangle: (1137,390) -> (1279,493)
# Bounding rectangle: (1162,388) -> (1279,433)
# 255
# Bounding rectangle: (665,415) -> (744,480)
# Bounding rectangle: (407,397) -> (583,518)
# Bounding rectangle: (606,422) -> (652,461)
# Bounding rectangle: (1013,402) -> (1068,426)
# Bounding rectangle: (1162,384) -> (1279,427)
# Bounding rectangle: (1106,401) -> (1160,425)
# 256
# Bounding rectangle: (661,418) -> (740,482)
# Bounding rectangle: (410,399) -> (582,521)
# Bounding rectangle: (604,429) -> (649,465)
# Bounding rectangle: (1008,403) -> (1064,432)
# Bounding rectangle: (1159,385) -> (1278,429)
# Bounding rectangle: (1088,403) -> (1154,429)
# 257
# Bounding rectangle: (410,401) -> (578,523)
# Bounding rectangle: (600,431) -> (648,471)
# Bounding rectangle: (658,421) -> (740,491)
# Bounding rectangle: (1097,407) -> (1170,434)
# Bounding rectangle: (1172,388) -> (1279,473)
# Bounding rectangle: (1011,407) -> (1080,442)
# 258
# Bounding rectangle: (664,415) -> (744,483)
# Bounding rectangle: (419,394) -> (586,519)
# Bounding rectangle: (1021,398) -> (1087,427)
# Bounding rectangle: (1116,398) -> (1180,424)
# Bounding rectangle: (604,426) -> (652,463)
# Bounding rectangle: (1189,379) -> (1279,426)
# Bounding rectangle: (1186,379) -> (1279,472)
# 259
# Bounding rectangle: (663,419) -> (744,486)
# Bounding rectangle: (413,400) -> (584,521)
# Bounding rectangle: (604,431) -> (652,467)
# Bounding rectangle: (1020,403) -> (1092,432)
# Bounding rectangle: (1097,402) -> (1186,430)
# Bounding rectangle: (1190,382) -> (1279,428)
# 260
# Bounding rectangle: (661,418) -> (741,484)
# Bounding rectangle: (420,398) -> (583,520)
# Bounding rectangle: (605,427) -> (650,465)
# Bounding rectangle: (1017,401) -> (1087,428)
# Bounding rectangle: (1195,379) -> (1279,424)
# Bounding rectangle: (1098,400) -> (1183,426)
# 261
# Bounding rectangle: (663,421) -> (742,488)
# Bounding rectangle: (421,403) -> (586,522)
# Bounding rectangle: (607,431) -> (651,467)
# Bounding rectangle: (1104,404) -> (1190,431)
# Bounding rectangle: (1019,405) -> (1095,435)
# Bounding rectangle: (1210,382) -> (1280,427)
# 262
# Bounding rectangle: (612,435) -> (658,473)
# Bounding rectangle: (430,405) -> (591,521)
# Bounding rectangle: (669,425) -> (748,493)
# Bounding rectangle: (1118,405) -> (1210,434)
# Bounding rectangle: (1031,406) -> (1111,436)
# 263
# Bounding rectangle: (421,411) -> (583,526)
# Bounding rectangle: (662,430) -> (741,496)
# Bounding rectangle: (604,437) -> (652,475)
# Bounding rectangle: (1114,408) -> (1207,437)
# ...
# Bounding rectangle: (334,435) -> (387,473)
# 1124
# Bounding rectangle: (649,389) -> (862,564)
# Bounding rectangle: (921,412) -> (1110,545)
# Bounding rectangle: (385,432) -> (443,488)
# Bounding rectangle: (492,431) -> (531,461)
# 1125
# Bounding rectangle: (653,391) -> (864,565)
# Bounding rectangle: (923,412) -> (1122,546)
# Bounding rectangle: (491,432) -> (543,462)
# Bounding rectangle: (384,434) -> (437,485)
# 1126
# Bounding rectangle: (655,392) -> (866,563)
# Bounding rectangle: (930,413) -> (1126,552)
# Bounding rectangle: (379,434) -> (437,487)
# Bounding rectangle: (488,434) -> (549,463)
# Bounding rectangle: (437,436) -> (479,471)
# 1127
# Bounding rectangle: (658,393) -> (868,566)
# Bounding rectangle: (933,414) -> (1138,555)
# Bounding rectangle: (381,438) -> (428,474)
# Bounding rectangle: (430,438) -> (477,471)
# Bounding rectangle: (488,434) -> (553,464)
# Bounding rectangle: (329,438) -> (385,481)
# 1128
# Bounding rectangle: (660,394) -> (868,567)
# Bounding rectangle: (939,414) -> (1144,558)
# Bounding rectangle: (380,439) -> (426,474)
# Bounding rectangle: (491,435) -> (535,463)
# Bounding rectangle: (419,439) -> (479,473)
# 1129
# Bounding rectangle: (663,394) -> (873,565)
# Bounding rectangle: (936,414) -> (1157,559)
# Bounding rectangle: (379,438) -> (431,474)
# Bounding rectangle: (491,435) -> (536,461)
# Bounding rectangle: (432,439) -> (478,471)
# 1130
# Bounding rectangle: (664,395) -> (877,567)
# Bounding rectangle: (949,412) -> (1168,564)
# Bounding rectangle: (378,439) -> (422,476)
# Bounding rectangle: (77,439) -> (216,510)
# Bounding rectangle: (427,440) -> (476,478)
# Bounding rectangle: (340,441) -> (385,482)
# Bounding rectangle: (488,437) -> (533,465)
# 1131
# Bounding rectangle: (664,396) -> (881,565)
# Bounding rectangle: (955,415) -> (1187,571)
# Bounding rectangle: (337,444) -> (382,483)
# Bounding rectangle: (376,440) -> (416,481)
# Bounding rectangle: (79,445) -> (207,514)
# Bounding rectangle: (485,438) -> (532,465)
# 1132
# Bounding rectangle: (667,396) -> (882,564)
# Bounding rectangle: (961,414) -> (1196,573)
# Bounding rectangle: (332,443) -> (382,483)
# Bounding rectangle: (375,441) -> (413,480)
# Bounding rectangle: (484,439) -> (534,468)
# 1133
# Bounding rectangle: (671,394) -> (882,563)
# Bounding rectangle: (962,411) -> (1210,575)
# Bounding rectangle: (374,441) -> (411,477)
# Bounding rectangle: (325,443) -> (382,483)
# Bounding rectangle: (476,438) -> (540,472)
# Bounding rectangle: (426,441) -> (467,477)
# Bounding rectangle: (946,430) -> (980,480)
# 1134
# Bounding rectangle: (674,395) -> (886,566)
# Bounding rectangle: (968,412) -> (1229,580)
# Bounding rectangle: (316,444) -> (378,484)
# Bounding rectangle: (950,431) -> (982,484)
# Bounding rectangle: (485,439) -> (532,469)
# Bounding rectangle: (372,442) -> (415,477)
# 1135
# Bounding rectangle: (675,394) -> (888,568)
# Bounding rectangle: (972,406) -> (1246,583)
# Bounding rectangle: (310,444) -> (378,487)
# Bounding rectangle: (380,441) -> (456,482)
# Bounding rectangle: (486,438) -> (538,467)
# Bounding rectangle: (192,441) -> (299,498)
# 1136
# Bounding rectangle: (677,393) -> (889,569)
# Bounding rectangle: (976,404) -> (1258,584)
# Bounding rectangle: (300,442) -> (377,483)
# Bounding rectangle: (374,440) -> (432,478)
# 1137
# Bounding rectangle: (685,393) -> (894,567)
# Bounding rectangle: (291,442) -> (375,484)
# Bounding rectangle: (976,402) -> (1273,587)
# Bounding rectangle: (489,438) -> (556,466)
# 1138
# Bounding rectangle: (687,393) -> (896,565)
# Bounding rectangle: (992,400) -> (1275,590)
# Bounding rectangle: (288,442) -> (370,486)
# Bounding rectangle: (486,437) -> (533,467)
# 1139
# Bounding rectangle: (689,393) -> (898,563)
# Bounding rectangle: (997,402) -> (1280,590)
# Bounding rectangle: (284,441) -> (365,487)
# Bounding rectangle: (365,440) -> (440,489)
# 1140
# Bounding rectangle: (692,393) -> (901,564)
# Bounding rectangle: (1006,403) -> (1278,596)
# Bounding rectangle: (281,442) -> (360,486)
# Bounding rectangle: (368,438) -> (442,486)
# 1141
# Bounding rectangle: (692,392) -> (901,564)
# Bounding rectangle: (1007,399) -> (1276,596)
# Bounding rectangle: (280,442) -> (356,484)
# Bounding rectangle: (361,438) -> (433,486)
# 1142
# Bounding rectangle: (697,394) -> (902,561)
# Bounding rectangle: (1018,410) -> (1280,600)
# Bounding rectangle: (358,441) -> (411,479)
# Bounding rectangle: (271,442) -> (346,488)
# Bounding rectangle: (482,438) -> (524,468)
# Bounding rectangle: (413,441) -> (460,476)
# 1143
# Bounding rectangle: (699,392) -> (909,561)
# Bounding rectangle: (1027,401) -> (1280,596)
# Bounding rectangle: (271,441) -> (346,487)
# Bounding rectangle: (361,438) -> (423,485)
# Bounding rectangle: (480,436) -> (525,469)
# Bounding rectangle: (417,440) -> (466,472)
# Bounding rectangle: (26,437) -> (153,501)
# 1144
# Bounding rectangle: (700,395) -> (910,564)
# Bounding rectangle: (1032,401) -> (1278,609)
# Bounding rectangle: (355,441) -> (414,487)
# Bounding rectangle: (477,438) -> (524,473)
# Bounding rectangle: (414,442) -> (465,486)
# Bounding rectangle: (9,440) -> (131,516)
# Bounding rectangle: (266,443) -> (350,493)
# 1145
# Bounding rectangle: (700,394) -> (911,562)
# Bounding rectangle: (1036,397) -> (1280,610)
# Bounding rectangle: (380,440) -> (461,493)
# Bounding rectangle: (263,443) -> (349,489)
# Bounding rectangle: (475,437) -> (519,470)
# Bounding rectangle: (346,441) -> (398,477)
# 1146
# Bounding rectangle: (705,394) -> (914,563)
# Bounding rectangle: (1047,397) -> (1280,621)
# Bounding rectangle: (352,440) -> (464,488)
# Bounding rectangle: (347,441) -> (394,480)
# Bounding rectangle: (474,437) -> (572,484)
# Bounding rectangle: (260,441) -> (351,488)
# 1147
# Bounding rectangle: (707,395) -> (916,565)
# Bounding rectangle: (1058,396) -> (1279,631)
# Bounding rectangle: (345,441) -> (394,483)
# Bounding rectangle: (254,442) -> (348,495)
# Bounding rectangle: (472,437) -> (567,472)
# Bounding rectangle: (356,440) -> (460,489)
# Bounding rectangle: (402,441) -> (462,485)
# 1148
# Bounding rectangle: (707,394) -> (916,565)
# Bounding rectangle: (1062,398) -> (1280,634)
# Bounding rectangle: (338,439) -> (387,486)
# Bounding rectangle: (250,442) -> (332,495)
# Bounding rectangle: (391,441) -> (457,488)
# 1149
# Bounding rectangle: (711,394) -> (918,568)
# Bounding rectangle: (1073,391) -> (1278,639)
# Bounding rectangle: (267,442) -> (340,490)
# Bounding rectangle: (342,441) -> (381,484)
# Bounding rectangle: (386,440) -> (456,487)
# 1150
# Bounding rectangle: (715,395) -> (919,568)
# Bounding rectangle: (1075,389) -> (1279,658)
# Bounding rectangle: (395,441) -> (446,479)
# Bounding rectangle: (90,433) -> (240,508)
# Bounding rectangle: (336,440) -> (399,486)
# Bounding rectangle: (263,443) -> (341,490)
# 1151
# Bounding rectangle: (718,398) -> (923,568)
# Bounding rectangle: (1092,399) -> (1275,658)
# Bounding rectangle: (251,444) -> (330,495)
# Bounding rectangle: (70,434) -> (232,511)
# Bounding rectangle: (390,442) -> (439,482)
# Bounding rectangle: (336,442) -> (396,488)
# 1152
# Bounding rectangle: (723,397) -> (922,564)
# Bounding rectangle: (1099,382) -> (1276,663)
# Bounding rectangle: (390,441) -> (438,480)
# Bounding rectangle: (65,432) -> (229,510)
# Bounding rectangle: (358,440) -> (396,479)
# 1153
# Bounding rectangle: (724,397) -> (923,565)
# Bounding rectangle: (1111,392) -> (1280,659)
# Bounding rectangle: (2,439) -> (81,529)
# Bounding rectangle: (229,444) -> (323,492)
# Bounding rectangle: (348,443) -> (392,482)
# Bounding rectangle: (45,434) -> (224,515)
# Bounding rectangle: (386,442) -> (440,481)
# 1154
# Bounding rectangle: (727,397) -> (925,566)
# Bounding rectangle: (218,444) -> (319,493)
# Bounding rectangle: (1120,383) -> (1280,661)
# Bounding rectangle: (46,433) -> (227,516)
# Bounding rectangle: (1,443) -> (77,531)
# Bounding rectangle: (331,441) -> (388,492)
# 1155
# Bounding rectangle: (727,397) -> (925,567)
# Bounding rectangle: (218,443) -> (319,493)
# Bounding rectangle: (327,441) -> (387,488)
# Bounding rectangle: (33,431) -> (205,523)
# Bounding rectangle: (1134,388) -> (1274,654)
# Bounding rectangle: (0,440) -> (60,530)
# Bounding rectangle: (381,442) -> (440,480)
# 1156
# Bounding rectangle: (726,400) -> (926,565)
# Bounding rectangle: (204,445) -> (305,503)
# Bounding rectangle: (316,443) -> (380,491)
# Bounding rectangle: (373,441) -> (438,486)
# Bounding rectangle: (16,432) -> (205,522)
# Bounding rectangle: (1146,403) -> (1279,661)
# 1157
# Bounding rectangle: (729,400) -> (928,563)
# Bounding rectangle: (201,443) -> (302,499)
# Bounding rectangle: (312,442) -> (379,490)
# Bounding rectangle: (371,440) -> (434,484)
# Bounding rectangle: (1161,491) -> (1278,652)
# Bounding rectangle: (8,437) -> (157,506)
# 1158
# Bounding rectangle: (730,402) -> (930,565)
# Bounding rectangle: (296,442) -> (375,497)
# Bounding rectangle: (1173,435) -> (1278,660)
# Bounding rectangle: (367,441) -> (431,488)
# Bounding rectangle: (196,443) -> (289,497)
# 1159
# Bounding rectangle: (730,402) -> (930,564)
# Bounding rectangle: (288,442) -> (371,491)
# Bounding rectangle: (186,443) -> (276,501)
# Bounding rectangle: (363,442) -> (421,484)
# 1160
# Bounding rectangle: (730,403) -> (931,564)
# Bounding rectangle: (288,441) -> (364,490)
# Bounding rectangle: (362,441) -> (417,484)
# 1161
# Bounding rectangle: (730,405) -> (932,564)
# Bounding rectangle: (279,441) -> (356,494)
# Bounding rectangle: (166,441) -> (282,498)
# Bounding rectangle: (360,442) -> (410,485)
# Bounding rectangle: (1221,487) -> (1280,665)
# 1162
# Bounding rectangle: (730,405) -> (929,565)
# Bounding rectangle: (275,440) -> (349,490)
# Bounding rectangle: (352,441) -> (407,485)
# Bounding rectangle: (164,442) -> (273,496)
# Bounding rectangle: (1238,505) -> (1279,660)
# 1163
# Bounding rectangle: (731,406) -> (929,562)
# Bounding rectangle: (157,443) -> (273,498)
# Bounding rectangle: (343,440) -> (405,485)
# Bounding rectangle: (269,441) -> (334,490)
# 1164
# Bounding rectangle: (731,405) -> (928,561)
# Bounding rectangle: (336,440) -> (400,485)
# Bounding rectangle: (181,443) -> (265,495)
# Bounding rectangle: (264,440) -> (331,492)
# 1165
# Bounding rectangle: (731,405) -> (927,564)
# Bounding rectangle: (169,443) -> (259,497)
# Bounding rectangle: (330,441) -> (395,488)
# Bounding rectangle: (256,441) -> (332,492)
# 1166
# Bounding rectangle: (731,404) -> (925,562)
# Bounding rectangle: (328,440) -> (391,485)
# Bounding rectangle: (155,442) -> (257,499)
# Bounding rectangle: (250,440) -> (329,491)
# Bounding rectangle: (2,437) -> (129,521)
# Bounding rectangle: (420,436) -> (484,473)
# 1167
# Bounding rectangle: (731,405) -> (924,561)
# Bounding rectangle: (133,442) -> (249,500)
# Bounding rectangle: (324,441) -> (381,486)
# Bounding rectangle: (417,438) -> (477,470)
# Bounding rectangle: (246,441) -> (332,492)
# 1168
# Bounding rectangle: (731,406) -> (925,564)
# Bounding rectangle: (106,443) -> (240,502)
# Bounding rectangle: (277,442) -> (331,492)
# Bounding rectangle: (319,441) -> (372,485)
# 1169
# Bounding rectangle: (731,407) -> (923,566)
# Bounding rectangle: (102,442) -> (234,499)
# Bounding rectangle: (263,441) -> (323,492)
# Bounding rectangle: (316,441) -> (362,476)
# 1170
# Bounding rectangle: (731,408) -> (922,568)
# Bounding rectangle: (247,441) -> (318,494)
# Bounding rectangle: (94,442) -> (244,500)
# Bounding rectangle: (309,440) -> (378,483)
# 1171
# Bounding rectangle: (729,409) -> (922,567)
# Bounding rectangle: (85,444) -> (216,502)
# Bounding rectangle: (234,441) -> (307,496)
# Bounding rectangle: (300,441) -> (370,492)
# 1172
# Bounding rectangle: (730,409) -> (921,568)
# Bounding rectangle: (69,442) -> (205,509)
# Bounding rectangle: (217,441) -> (302,498)
# Bounding rectangle: (298,441) -> (365,481)
# Bounding rectangle: (0,430) -> (62,516)
# 1173
# Bounding rectangle: (729,409) -> (920,567)
# Bounding rectangle: (204,441) -> (304,499)
# Bounding rectangle: (63,442) -> (200,512)
# Bounding rectangle: (297,440) -> (366,478)
# Bounding rectangle: (0,433) -> (57,520)
# 1174
# Bounding rectangle: (729,409) -> (919,566)
# Bounding rectangle: (50,441) -> (197,509)
# Bounding rectangle: (195,440) -> (291,499)
# Bounding rectangle: (295,441) -> (360,478)
# 1175
# Bounding rectangle: (728,410) -> (918,565)
# Bounding rectangle: (182,441) -> (283,500)
# Bounding rectangle: (40,441) -> (180,517)
# Bounding rectangle: (284,442) -> (352,479)
# 1176
# Bounding rectangle: (726,409) -> (915,566)
# Bounding rectangle: (180,440) -> (276,498)
# Bounding rectangle: (30,442) -> (187,511)
# Bounding rectangle: (281,440) -> (348,481)
# Bounding rectangle: (136,442) -> (188,500)
# 1177
# Bounding rectangle: (725,409) -> (914,560)
# Bounding rectangle: (112,442) -> (182,501)
# Bounding rectangle: (174,440) -> (259,494)
# Bounding rectangle: (267,440) -> (344,483)
# Bounding rectangle: (374,436) -> (470,482)
# Bounding rectangle: (27,447) -> (126,504)
# 1178
# Bounding rectangle: (725,408) -> (913,559)
# Bounding rectangle: (77,442) -> (173,508)
# Bounding rectangle: (259,441) -> (334,481)
# Bounding rectangle: (166,440) -> (247,500)
# 1179
# Bounding rectangle: (725,406) -> (912,557)
# Bounding rectangle: (41,442) -> (167,507)
# Bounding rectangle: (253,439) -> (332,482)
# Bounding rectangle: (167,438) -> (261,497)
# 1180
# Bounding rectangle: (724,404) -> (911,555)
# Bounding rectangle: (21,438) -> (170,505)
# Bounding rectangle: (245,438) -> (326,486)
# Bounding rectangle: (163,436) -> (253,497)
# 1181
# Bounding rectangle: (721,404) -> (909,556)
# Bounding rectangle: (2,439) -> (145,512)
# Bounding rectangle: (241,438) -> (317,484)
# Bounding rectangle: (156,438) -> (240,496)
# 1182
# Bounding rectangle: (722,404) -> (909,555)
# Bounding rectangle: (1,442) -> (130,518)
# Bounding rectangle: (131,438) -> (242,493)
# Bounding rectangle: (236,440) -> (302,481)
# 1183
# Bounding rectangle: (721,405) -> (908,555)
# Bounding rectangle: (0,440) -> (128,513)
# Bounding rectangle: (232,438) -> (309,481)
# Bounding rectangle: (168,437) -> (237,494)
# 1184
# Bounding rectangle: (720,405) -> (908,554)
# Bounding rectangle: (0,440) -> (121,516)
# Bounding rectangle: (140,438) -> (227,502)
# Bounding rectangle: (220,438) -> (304,485)
# 1185
# Bounding rectangle: (719,406) -> (905,555)
# Bounding rectangle: (114,438) -> (221,500)
# Bounding rectangle: (216,439) -> (291,485)
# Bounding rectangle: (0,440) -> (102,509)
# Bounding rectangle: (354,436) -> (404,470)
# 1186
# Bounding rectangle: (718,406) -> (905,555)
# Bounding rectangle: (100,436) -> (223,501)
# Bounding rectangle: (1,438) -> (87,509)
# Bounding rectangle: (209,438) -> (296,480)
# Bounding rectangle: (341,427) -> (475,494)
# 1187
# Bounding rectangle: (719,406) -> (904,553)
# Bounding rectangle: (83,436) -> (216,497)
# Bounding rectangle: (245,438) -> (290,472)
# Bounding rectangle: (203,437) -> (290,481)
# Bounding rectangle: (0,437) -> (102,509)
# 1188
# Bounding rectangle: (717,405) -> (901,552)
# Bounding rectangle: (70,434) -> (205,496)
# Bounding rectangle: (229,438) -> (285,473)
# Bounding rectangle: (2,436) -> (83,503)
# 1189
# Bounding rectangle: (717,407) -> (897,550)
# Bounding rectangle: (70,435) -> (190,495)
# Bounding rectangle: (229,438) -> (278,470)
# Bounding rectangle: (15,434) -> (154,507)
# 1190
# Bounding rectangle: (718,405) -> (899,548)
# Bounding rectangle: (0,434) -> (74,507)
# Bounding rectangle: (53,431) -> (185,497)
# Bounding rectangle: (192,432) -> (267,504)
# 1191
# Bounding rectangle: (716,405) -> (895,549)
# Bounding rectangle: (45,432) -> (164,492)
# Bounding rectangle: (176,433) -> (251,482)
# Bounding rectangle: (3,433) -> (63,497)
# 1192
# Bounding rectangle: (714,405) -> (894,548)
# Bounding rectangle: (1,432) -> (62,500)
# Bounding rectangle: (168,434) -> (259,479)
# Bounding rectangle: (39,432) -> (199,506)
# 1193
# Bounding rectangle: (712,406) -> (889,544)
# Bounding rectangle: (158,433) -> (226,493)
# Bounding rectangle: (6,428) -> (162,503)
# Bounding rectangle: (0,433) -> (37,497)
# 1194
# Bounding rectangle: (713,405) -> (891,543)
# 1195
# Bounding rectangle: (710,402) -> (887,542)
# 1196
# Bounding rectangle: (710,402) -> (886,543)
# Bounding rectangle: (36,425) -> (166,505)
# 1197
# Bounding rectangle: (710,397) -> (884,537)
# Bounding rectangle: (23,425) -> (139,497)
# 1198
# Bounding rectangle: (704,394) -> (880,536)
# Bounding rectangle: (0,419) -> (131,493)
# Bounding rectangle: (136,418) -> (221,471)
# 1199
# Bounding rectangle: (701,394) -> (874,537)
# Bounding rectangle: (1,418) -> (155,492)
# 1200
# Bounding rectangle: (704,392) -> (874,533)
# Bounding rectangle: (0,418) -> (100,493)
# 1201
# Bounding rectangle: (700,390) -> (873,535)
# Bounding rectangle: (1,417) -> (92,488)
# Bounding rectangle: (90,416) -> (201,479)
# 1202
# Bounding rectangle: (696,393) -> (872,534)

# %%
def annotate_video_with_make(detections, input_video_path, output_video_path):
    color=(0,255,0)
    thickness=3

    vcap = cv2.VideoCapture(input_path)
    width = int(vcap.get(3))
    height = int(vcap.get(4))
    fps = vcap.get(5)
    fourcc = cv2.VideoWriter_fourcc(*'H264') #codec
    video=cv2.VideoWriter(output_path, fourcc, fps, (width,height))

    frame_id = 0
    # Capture frame-by-frame
    ret, frame = vcap.read()  # ret = 1 if the video is captured; frame is the image

    while ret:
        df = detections
        df = df[['boxes', 'labels', 'make_prediction']][df.id == frame_id]
        if df.size:
            for bbox, label, make_prediction in df.values:
                if label == 'car':
                    x1, y1 = bbox[0]
                    x2, y2 = bbox[1]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                    img=cv2.rectangle(frame, (x1, y1), (x2, y2), color, thickness) # object bbox
                    cv2.putText(img, make_prediction, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, thickness-1) # object label
            video.write(img)

        frame_id+=1
        ret, frame = vcap.read()

    video.release()
    vcap.release()

# %%
car_detections
# Out:
#        id                                              boxes         labels  \
# 0     407  [[461.095123291, 421.1968688965], [554.2673339...            car
# 1     407  [[559.2814331055, 419.9615783691], [656.066711...            car
# 2     407  [[645.993347168, 433.1330566406], [682.3140258...            car
# 3     408  [[463.528503418, 422.7390136719], [555.3230590...            car
# 4     408  [[644.3532104492, 434.6446228027], [680.485046...            car
# ...   ...                                                ...            ...
# 7500  180  [[344.4665527344, 307.2627258301], [371.658508...  traffic light
# 7501  180  [[208.8990478516, 152.3822479248], [237.628417...  traffic light
# 7502  180  [[1052.2082519531, 404.5354614258], [1079.6346...         person
# 7503  180  [[34.9946212769, 343.8520812988], [287.7828979...            bus
# 7504  180  [[1232.6459960938, 215.3074798584], [1278.1768...  traffic light
#
#         scores make_prediction
# 0     0.997653            Ford
# 1     0.997329            Ford
# 2     0.996911             Geo
# 3     0.998743            Ford
# 4     0.996526             Geo
# ...        ...             ...
# 7500  0.989451            None
# 7501  0.982935            None
# 7502  0.981206            None
# 7503  0.909774            None
# 7504  0.853543            None
#
# [7505 rows x 5 columns]

# %%
from ipywidgets import Video
input_path = '../data/bdd_test/bdd_1.mp4'
output_path = 'bdd_video_make.mp4'
annotate_video_with_make(car_detections, input_path, output_path)
Video.from_file(output_path)
# Out:
# Video(value=b'\x00\x00\x00 ftypisom\x00\x00\x02\x00isomiso2avc1mp41\x00\x00\x00\x08free\x01\x17\x1b\xc6mdat\x0…
